# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
ind_data1=pd.read_csv('Indian_airline_dataset.csv')
ind_data1.head()
# Out:
#     Used Date From   To   Airline Scheduled Departure  SDEP Departure   DEP  \
# 0  31-01-2020  DEL  HYD  Air Asia               06:05   605     06:04   604
# 1  31-01-2020  DEL  HYD    Indigo               04:50   450     04:36   436
# 2  30-01-2020  DEL  HYD  Air Asia               06:05   605     05:54   554
# 3  30-01-2020  DEL  HYD  Air Asia               17:40  1740     17:40  1740
# 4  30-01-2020  DEL  HYD  Air Asia               19:50  1950     19:54  1954
#
#   Scheduled Arrival  SARR  ... Market Share  OTP Index  \
# 0             08:15   815  ...          5.3       85.6
# 1             07:00   700  ...         47.5       81.1
# 2             08:15   815  ...          5.3       85.6
# 3             19:55  1955  ...          5.3       85.6
# 4             22:10  2210  ...          5.3       85.6
#
#    weather__hourly__windspeedKmph  weather__hourly__weatherDesc__value  \
# 0                              11                        Partly cloudy
# ...

# %%
ind_data1.shape
# Out:
# (10718, 29)

# %%
ind_data1.isnull().sum()
# Out:
# Used Date                              0
# From                                   0
# To                                     0
# Airline                                0
# Scheduled Departure                    0
# SDEP                                   0
# Departure                              0
# DEP                                    0
# Scheduled Arrival                      0
# SARR                                   0
# Arrival                                0
# ARR                                    0
# Departure Delay                        0
# Arrival Delay                          0
# Status                                 0
# Distance                               0
# Passenger Load Factor                  0
# Airline Rating                         0
# Airport Rating                         0
# Market Share                           0
# OTP Index                              0
# weather__hourly__windspeedKmph         0
# weather__hourly__weatherDesc__value    0
# ...

# %%
differences_SDEP = ind_data1[ind_data1['Scheduled Departure'].str.replace(':', '').astype(int) != ind_data1['SDEP']]
print(f"The Difference between 'Scheduled Departure' and 'SDEP' is {differences_SDEP.shape[0]}")

differences_DEP = ind_data1[ind_data1['Departure'].str.replace(':', '').astype(int) != ind_data1['DEP']]
print(f"The Difference between 'Departure' and 'DEP' is {differences_DEP.shape[0]}")

differences_SARR = ind_data1[ind_data1['Scheduled Arrival'].str.replace(':', '').astype(int) != ind_data1['SARR']]
print(f"The Difference between 'Scheduled Arrival' and 'SARR' is {differences_SARR.shape[0]}")

differences_ARR = ind_data1[ind_data1['Arrival'].str.replace(':', '').astype(int) != ind_data1['ARR']]
print(f"The Difference between 'Arrival' and 'ARR' is {differences_ARR.shape[0]}")
# Out:
# The Difference between 'Scheduled Departure' and 'SDEP' is 0
# The Difference between 'Departure' and 'DEP' is 689
# The Difference between 'Scheduled Arrival' and 'SARR' is 0
# The Difference between 'Arrival' and 'ARR' is 81

# %%
differences_DEP.head()
# Out:
#       Used Date From   To Airline Scheduled Departure  SDEP Departure   DEP  \
# 194  28-01-2020  BOM  DEL  Go Air               21:15  2115     21:15  2113
# 195  28-01-2020  BOM  DEL  Go Air               21:15  2115     21:13  2115
# 211  28-01-2020  BLR  BOM  Indigo               06:05   605     06:01   553
# 212  28-01-2020  BOM  DEL  Indigo               06:05   605     05:53   601
# 252  28-01-2020  BOM  DEL  Indigo               20:55  2055     20:55  2053
#
#     Scheduled Arrival  SARR  ... Market Share  OTP Index  \
# 194             23:30  2330  ...         11.0       87.2
# 195             23:30  2330  ...         11.0       87.2
# 211             07:50   750  ...         47.5       81.1
# 212             08:15   815  ...         47.5       81.1
# 252             23:20  2320  ...         47.5       81.1
#
#      weather__hourly__windspeedKmph  weather__hourly__weatherDesc__value  \
# 194                              18                               Cloudy
# ...

# %%
ind_data1['From'].unique()
# Out:
# array(['DEL', 'BLR', 'BOM', 'CCU'], dtype=object)
